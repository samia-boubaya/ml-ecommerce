# %% [markdown]
# <hr>
#
# # 📖 README (Details) 📖
#
# <style>
# h1 {
#     text-align: center;
#     color: orange;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h2 {
#     text-align: center;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h3 {
#     text-align: center;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h4 {
#     text-align: center;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <hr>

# %% [markdown]
# ## 🛒 **E-Commerce Customer Purchase Prediction**
#
# Predict customer purchase intent in an e-commerce environment using session and behavioral data. 🎯
#
# ---
# ## 📌 Project Overview
#
# This project focuses on **predicting whether a website visitor will make a purchase** during an online shopping session.
#
# By identifying visitors with high purchase intent, businesses can optimize **targeting, personalization, and retargeting strategies**, ultimately boosting **revenue and conversion rates**. 💰
#
# **Target: REVENUE (Categorical)**
# - 🟢 <span style="color:green"><b>Buy</b></span>
# - 🔴 <span style="color:red"><b>Not Buy</b></span>
#
#
# **Business Impact:**
# - 🎯 Improved marketing targeting
# - ✨ Personalized user experience
# - 📈 Higher conversion rates and sales
#
# ---
# ## 📂 Dataset
#
# We use the **Online Shoppers Purchasing Intention Dataset**, which contains detailed information about visitor sessions.
#
# **Features include:**
# - 📝 Pages visited
# - ⏱️ Session duration
# - 💳 Cart value
# - 📱 Device type
# - 🌐 Traffic source
# - 🛍️ Past purchases
#
# **Sources:**
# - [UCI Machine Learning Repository](https://archive.ics.uci.edu/dataset/468/online+shoppers+purchasing+intention+dataset)
# - [Kaggle Dataset](https://www.kaggle.com/datasets/henrysue/online-shoppers-intention)
#
# ---
# ## 🔑 Features
# ---
# ## 📊 Dataset Overview
#
# The Raw Dataset is suitable for ML modeling.
#
# |Number of rows|Number of columns|
# |-----------|-------|
# | 12_330 | 18 |
#
# ```text
# ```
#
# ---
# ## 🔑 Features Description
#
# | Feature | Type | Description |
# |---------|------|-------------|
# | `Administrative` | int64 | Number of administrative pages visited in the session (e.g., site info, help pages). Values are derived from the URL and updated in real time. |
# | `Administrative_Duration` | float64 | Total time (in seconds) spent on administrative pages during the session. |
# | `Informational` | int64 | Number of informational pages visited (e.g., product guides, info pages). |
# | `Informational_Duration` | float64 | Total time spent on informational pages during the session. |
# | `ProductRelated` | int64 | Number of product-related pages visited (e.g., product listings, product details). |
# | `ProductRelated_Duration` | float64 | Total time spent on product-related pages during the session. |
# | `BounceRates` | float64 | Percentage of visitors who enter the site from a page and leave without triggering other requests ("bounce"). Measured by Google Analytics. |
# | `ExitRates` | float64 | Percentage of visits to a page that were the last in the session. Measured by Google Analytics. |
# | `PageValues` | float64 | Average value of a web page based on transactions. Measured by Google Analytics. |
# | `SpecialDay` | float64 | Closeness of the visit to a special day (e.g., Valentine’s Day, Mother’s Day). Value ranges from 0–1 depending on proximity to the special day. 🎉 |
# | `Month` | object | Month of the session (Jan–Dec) 📆 |
# | `OperatingSystems` | int64 | ID of the operating system used by the visitor (e.g., Windows, Mac) 🖥️ |
# | `Browser` | int64 | ID of the browser used by the visitor (e.g., Chrome, Firefox) |
# | `Region` | int64 | Numeric code representing the geographic region of the visitor |
# | `TrafficType` | int64 | Numeric code indicating traffic source (e.g., direct, referral, search engine) |
# | `VisitorType` | object | Indicates whether the visitor is new or returning 👤 |
# | `Weekend` | bool | Boolean indicating whether the visit occurred on a weekend 🛌 |
# | `Revenue` | bool | Target column: whether the session resulted in a purchase. 1 = Buy, 0 = Not Buy 💰 |
#
# ```text
# ```
# ---
# ## ⚙️ Methodology
#
# 1. **Data Preprocessing** 🧹
#    - Handle missing values
#    - Encode categorical features
#    - Normalize numerical features
#
# 2. **Exploratory Data Analysis (EDA)** 🔍
#    - Analyze session patterns
#    - Identify trends and correlations with purchase behavior
#
# 3. **Modeling** 🤖
#    - Classification models (e.g., Logistic Regression, Random Forest, XGBoost)
#    - Model evaluation with accuracy, precision, recall, F1-score
#
# 4. **Deployment (Optional)** 🚀
#    - Predict purchase intent in real-time for live sessions
#    - Integrate predictions with personalization and marketing tools
#
# ---
# ## 🎯 Goals
#
# - Identify sessions with high likelihood of purchase 🛍️
# - Optimize marketing spend and retargeting campaigns 💸
# - Increase conversion rate and customer satisfaction 😃
#
# ---
# ## 📜 License
#
# This project uses publicly available datasets.
#
# ---
# ## 🗂 Project Folder Structure
#
# ```text
# ml-ecommerce/
# │
# ├─ README.md
# │
# ├─ dashboards/
# │
# ├─ data/
# │   ├─ processed/
# │   │   ├─ online_shoppers_intention_01_standard.csv
# │   │   ├─ online_shoppers_intention_02_invalid-values.csv
# │   │   ├─ online_shoppers_intention_03_data-types.csv
# │   │   ├─ online_shoppers_intention_04_null-values.csv
# │   │   ├─ online_shoppers_intention_05_duplicates-values.csv
# │   │   └─ online_shoppers_intention_06-clean.csv
# │   └─ raw/
# │       └─ online_shoppers_intention.csv
# │
# ├─ feedback/
# │
# ├─ notebooks/
# │   ├─ S0_readme.ipynb
# │   ├─ S1_data-exploration.ipynb
# │   ├─ S2_data-cleaning.ipynb
# │   ├─ S3_data-analysis.ipynb
# │   ├─ S4_statistics.ipynb
# │   ├─ S5_ml.ipynb
# │   └─ S6_plots.ipynb
# │
# └─ plots/
# ```
#
# ---
